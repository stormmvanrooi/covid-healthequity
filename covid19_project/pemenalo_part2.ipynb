# %%
import pandas as pd
import numpy as np
import matplotlib
import requests
import json

# %%
barriers_df = pd.read_csv("Resources\CVAC_data_Feb2021.csv")
barriers_df.head()
# Out:
#    FIPS       State  Th1_Historic_Undervaccination  \
# 0     1     Alabama                           0.36
# 1     2      Alaska                           0.98
# 2     4     Arizona                           0.92
# 3     5    Arkansas                           0.34
# 4     6  California                           0.80
#
#    Th2_Sociodemographic_Barriers  Th3_Resource_constrained_Healthcare_System  \
# 0                           0.88                                        0.52
# 1                           0.16                                        0.14
# 2                           0.52                                        0.96
# 3                           0.96                                        0.74
# 4                           0.44                                        0.80
#
#    Th4_Healthcare_Accessibility_Barriers  Th5_Irregular_Care_Seeking_Behavior  \
# 0                                   0.96                                 0.80
# 1                                   0.98                                 0.96
# 2                                   0.38                                 0.92
# 3                                   0.88                                 0.78
# 4                                   0.08                                 0.96
#
#    CVAC
# 0  0.78
# 1  0.70
# 2  0.88
# 3  0.88
# 4  0.68

# %%
deaths_vaccstatus_df = pd.read_csv("Resources\cases_and_deaths_by_vaccination_status.csv")
deaths_vaccstatus_df.head()
# Out:
#   outcome     month  mmwr_week      week_date age_group vaccine_product  \
# 0    case  04 - APR         14  Apr 04-Apr 10     12-17       all_types
# 1    case  04 - APR         14  Apr 04-Apr 10     18-29       all_types
# 2    case  04 - APR         14  Apr 04-Apr 10     30-49       all_types
# 3    case  04 - APR         14  Apr 04-Apr 10     50-64       all_types
# 4    case  04 - APR         14  Apr 04-Apr 10     65-79       all_types
#
#    crude_vax_ir  crude_unvax_ir  crude_irr
# 0     14.021312      231.534316  16.513027
# 1     33.231686      274.515844   8.260666
# 2     30.460406      250.979057   8.239518
# 3     26.446469      192.311420   7.271724
# 4     13.722635      159.418827  11.617217

# %%
hospitilizations_df = pd.read_csv(r"Resources\associated_hospitalizations_by_vaccine_status_in_adults_january-august_2021.csv")
hospitilizations_df.head()
# Out:
#   Week ending Age group  Rate in unvaccinated  Rate in fully vaccinated
# 0     1/30/21    65+ yr                  34.4                       0.0
# 1     1/30/21  50-64 yr                  21.2                       1.2
# 2     1/30/21  18-49 yr                   6.3                       0.0
# 3      2/6/21    65+ yr                  43.2                       6.4
# 4      2/6/21  50-64 yr                  15.4                       0.0

# %%
# COVID19 Case Surveillance

covid19_surv_url = "https://data.cdc.gov/resource/n8mc-b4w4.json"
response1 = requests.get(covid19_surv_url)
response1
# Out:
# <Response [200]>

# %%
response1.json()
# Out:
# [{'case_month': '2020-11',
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'POSEY',
#   'county_fips_code': '18129',
#   'age_group': '0 - 17 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-03',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'WOODFORD',
#   'county_fips_code': '21239',
#   'age_group': '0 - 17 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-08',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'ANTRIM',
#   'county_fips_code': '26009',
#   'age_group': '18 to 49 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-07',
#   'res_state': 'WA',
#   'state_fips_code': '53',
#   'res_county': 'ASOTIN',
#   'county_fips_code': '53003',
#   'age_group': '18 to 49 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-07',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'IOWA',
#   'county_fips_code': '55049',
#   'age_group': '18 to 49 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'Unknown'},
#  {'case_month': '2021-06',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'VENANGO',
#   'county_fips_code': '42121',
#   'age_group': '50 to 64 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'NA'},
#  {'case_month': '2020-12',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'BULLITT',
#   'county_fips_code': '21029',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-12',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'CLINTON',
#   'county_fips_code': '17027',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-05',
#   'res_state': 'MA',
#   'state_fips_code': '25',
#   'res_county': 'FRANKLIN',
#   'county_fips_code': '25011',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-12',
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'LAWRENCE',
#   'county_fips_code': '18093',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-03',
#   'res_state': 'NY',
#   'state_fips_code': '36',
#   'res_county': 'LEWIS',
#   'county_fips_code': '36049',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-01',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'MUSKINGUM',
#   'county_fips_code': '39119',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-02',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'PRINCE GEORGE',
#   'county_fips_code': '51149',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'PUTNAM',
#   'county_fips_code': '39137',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Multiple',
#   'exposure_yn': 'Yes',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-02',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'WAYNE',
#   'county_fips_code': '39169',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Unknown',
#   'exposure_yn': 'Unknown',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'IA',
#   'state_fips_code': '19',
#   'res_county': 'CERRO GORDO',
#   'county_fips_code': '19033',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-09',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'COLES',
#   'county_fips_code': '17029',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-08',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'DICKSON',
#   'county_fips_code': '47043',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'DYER',
#   'county_fips_code': '47045',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-03',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'EATON',
#   'county_fips_code': '26045',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-01',
#   'res_state': 'AR',
#   'state_fips_code': '05',
#   'res_county': 'HOT SPRING',
#   'county_fips_code': '05059',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-03',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'LAPEER',
#   'county_fips_code': '26087',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-10',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'MACOUPIN',
#   'county_fips_code': '17117',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-08',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'MCNAIRY',
#   'county_fips_code': '47109',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-08',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'PICKENS',
#   'county_fips_code': '13227',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-07',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'PORTSMOUTH CITY',
#   'county_fips_code': '51740',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-08',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'ROSS',
#   'county_fips_code': '39141',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2021-09',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'WAYNE',
#   'county_fips_code': '42127',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'Unknown'},
#  {'case_month': '2020-11',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'LASALLE',
#   'county_fips_code': '17099',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-08',
#   'res_state': 'NH',
#   'state_fips_code': '33',
#   'res_county': 'BELKNAP',
#   'county_fips_code': '33001',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'NA'},
#  {'case_month': '2020-07',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'PULASKI',
#   'county_fips_code': '21199',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2021-08',
#   'res_state': 'AL',
#   'state_fips_code': '01',
#   'res_county': 'LAWRENCE',
#   'county_fips_code': '47099',
#   'age_group': 'Missing',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Unknown',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-09',
#   'res_state': 'ND',
#   'state_fips_code': '38',
#   'res_county': 'BURLEIGH',
#   'county_fips_code': '38015',
#   'age_group': '0 - 17 years',
#   'sex': 'Male',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-02',
#   'res_state': 'IN',
#   'state_fips_code': '21',
#   'res_county': 'DAVIESS',
#   'county_fips_code': '21059',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-03',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'DUNN',
#   'county_fips_code': '55033',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'Unknown'},
#  {'case_month': '2020-12',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'MASON',
#   'county_fips_code': '26105',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-01',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'CARROLL',
#   'county_fips_code': '13045',
#   'age_group': '0 - 17 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-12',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'MCCRACKEN',
#   'county_fips_code': '21145',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-04',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'FLUVANNA',
#   'county_fips_code': '51065',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-07',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'TRUMBULL',
#   'county_fips_code': '39155',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Contact tracing of case patient',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'Yes',
#   'death_yn': 'No',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-11',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'ASHTABULA',
#   'county_fips_code': '39007',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-10',
#   'res_state': 'NY',
#   'state_fips_code': '36',
#   'res_county': 'SARATOGA',
#   'county_fips_code': '36091',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'SMITH',
#   'county_fips_code': '47159',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'WHITE',
#   'county_fips_code': '47185',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'White',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-01',
#   'res_state': 'WA',
#   'state_fips_code': '53',
#   'res_county': 'BENTON',
#   'county_fips_code': '53005',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'No',
#   'death_yn': 'Missing',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-07',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'WAKE',
#   'county_fips_code': '37183',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Unknown',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-10',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'BROWN',
#   'county_fips_code': '55009',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-05',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'CHESTERFIELD',
#   'county_fips_code': '51041',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-08',
#   'res_state': 'OK',
#   'state_fips_code': '40',
#   'res_county': 'COMANCHE',
#   'county_fips_code': '40031',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'Unknown'},
#  {'case_month': '2020-10',
#   'res_state': 'WA',
#   'state_fips_code': '53',
#   'res_county': 'PIERCE',
#   'county_fips_code': '53053',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-03',
#   'res_state': 'NV',
#   'state_fips_code': '32',
#   'res_county': 'WASHOE',
#   'county_fips_code': '32031',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Routine surveillance',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'CT',
#   'state_fips_code': '09',
#   'res_county': 'NEW LONDON',
#   'county_fips_code': '09011',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-07',
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'ELKHART',
#   'county_fips_code': '18039',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-04',
#   'res_state': 'KS',
#   'state_fips_code': '20',
#   'res_county': 'FORD',
#   'county_fips_code': '20057',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-05',
#   'res_state': 'NJ',
#   'state_fips_code': '34',
#   'res_county': 'MERCER',
#   'county_fips_code': '34021',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2021-01',
#   'res_state': 'NJ',
#   'state_fips_code': '34',
#   'res_county': 'ATLANTIC',
#   'county_fips_code': '34001',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Black',
#   'ethnicity': 'Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'MD',
#   'state_fips_code': '24',
#   'res_county': "PRINCE GEORGE'S",
#   'county_fips_code': '24033',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-02',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'NORFOLK CITY',
#   'county_fips_code': '51710',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Multiple/Other',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'UT',
#   'state_fips_code': '49',
#   'res_county': 'SALT LAKE',
#   'county_fips_code': '49035',
#   'age_group': '0 - 17 years',
#   'sex': 'Male',
#   'race': 'Native Hawaiian/Other Pacific Islander',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Laboratory reported',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2020-06',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'WAYNE',
#   'county_fips_code': '37191',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Asymptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2021-08',
#   'res_state': 'CA',
#   'state_fips_code': '06',
#   'res_county': 'COLUSA',
#   'county_fips_code': '06011',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'MANITOWOC',
#   'county_fips_code': '55071',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-05',
#   'res_state': 'MN',
#   'state_fips_code': '27',
#   'res_county': 'RICE',
#   'county_fips_code': '27131',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-05',
#   'res_state': 'IA',
#   'state_fips_code': '19',
#   'res_county': 'WOODBURY',
#   'county_fips_code': '19193',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2020-05',
#   'res_state': 'MD',
#   'state_fips_code': '24',
#   'res_county': 'CARROLL',
#   'county_fips_code': '24013',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-07',
#   'res_state': 'AL',
#   'state_fips_code': '01',
#   'res_county': 'HOUSTON',
#   'county_fips_code': '13153',
#   'age_group': 'Missing',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Non-Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'LINCOLN',
#   'county_fips_code': '21137',
#   'age_group': '0 - 17 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-06',
#   'res_state': 'UT',
#   'state_fips_code': '49',
#   'res_county': 'SANPETE',
#   'county_fips_code': '49039',
#   'age_group': '18 to 49 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2021-05',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'VERNON',
#   'county_fips_code': '55123',
#   'age_group': '18 to 49 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-07',
#   'res_state': 'GA',
#   'state_fips_code': '12',
#   'res_county': 'LEE',
#   'county_fips_code': '12071',
#   'age_group': '50 to 64 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-08',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'BARTOW',
#   'county_fips_code': '13015',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-01',
#   'res_state': 'FL',
#   'state_fips_code': '12',
#   'res_county': 'BRADFORD',
#   'county_fips_code': '12007',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'CAROLINE',
#   'county_fips_code': '51033',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-02',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'CHEBOYGAN',
#   'county_fips_code': '26031',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-04',
#   'res_state': 'CA',
#   'state_fips_code': '06',
#   'res_county': 'DEL NORTE',
#   'county_fips_code': '06015',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'NY',
#   'state_fips_code': '36',
#   'res_county': 'DELAWARE',
#   'county_fips_code': '36025',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-07',
#   'res_state': 'ID',
#   'state_fips_code': '16',
#   'res_county': 'ELMORE',
#   'county_fips_code': '16039',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'FAYETTE',
#   'county_fips_code': '39047',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Multiple',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2021-08',
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'JENNINGS',
#   'county_fips_code': '18079',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-02',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'MCDOWELL',
#   'county_fips_code': '37111',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Unknown',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'NORTHUMBERLAND',
#   'county_fips_code': '42097',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'Unknown'},
#  {'case_month': '2021-09',
#   'res_state': 'SC',
#   'state_fips_code': '45',
#   'res_county': 'OCONEE',
#   'county_fips_code': '45073',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-11',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'PERRY',
#   'county_fips_code': '21193',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-08',
#   'res_state': 'KS',
#   'state_fips_code': '20',
#   'res_county': 'POTTAWATOMIE',
#   'county_fips_code': '20149',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2021-08',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'YADKIN',
#   'county_fips_code': '37197',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-10',
#   'res_state': 'IN',
#   'state_fips_code': '21',
#   'res_county': 'ALLEN',
#   'county_fips_code': '21003',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'BOTETOURT',
#   'county_fips_code': '51023',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-11',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'FRANKLIN',
#   'county_fips_code': '47051',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-08',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'HABERSHAM',
#   'county_fips_code': '13137',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-08',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'KANKAKEE',
#   'county_fips_code': '17091',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'LIVINGSTON',
#   'county_fips_code': '17105',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'FL',
#   'state_fips_code': '12',
#   'res_county': 'SUMTER',
#   'county_fips_code': '12119',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-01',
#   'res_state': 'SC',
#   'state_fips_code': '45',
#   'res_county': 'SUMTER',
#   'county_fips_code': '45085',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-12',
#   'res_state': 'SD',
#   'state_fips_code': '46',
#   'res_county': 'YANKTON',
#   'county_fips_code': '46135',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-08',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'CRAWFORD',
#   'county_fips_code': '42039',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2021-01',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'FAUQUIER',
#   'county_fips_code': '51061',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-06',
#   'res_state': 'IA',
#   'state_fips_code': '19',
#   'res_county': 'JONES',
#   'county_fips_code': '19105',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-12',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'SCOTT',
#   'county_fips_code': '51169',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-08',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'SHELBY',
#   'county_fips_code': '39149',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-09',
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'WHITE',
#   'county_fips_code': '18181',
#   'age_group': '50 to 64 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-10',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'NA',
#   'county_fips_code': 'NA',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'No',
#   'death_yn': 'NA'},
#  {'case_month': '2021-08',
#   'res_state': 'ID',
#   'state_fips_code': '16',
#   'res_county': 'KOOTENAI',
#   'county_fips_code': '16055',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-05',
#   'res_state': 'MS',
#   'state_fips_code': '28',
#   'res_county': 'WASHINGTON',
#   'county_fips_code': '28151',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-12',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'ADAMS',
#   'county_fips_code': '39001',
#   'age_group': '0 - 17 years',
#   'sex': 'Male',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'No',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'DOOR',
#   'county_fips_code': '55029',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-07',
# ...
#   'res_state': 'IN',
#   'state_fips_code': '18',
#   'res_county': 'HAMILTON',
#   'county_fips_code': '18057',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Asian',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'MITCHELL',
#   'county_fips_code': '13205',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Black',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-09',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'PERSON',
#   'county_fips_code': '37145',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Black',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Unknown',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'SUFFOLK CITY',
#   'county_fips_code': '51800',
#   'age_group': '0 - 17 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'AUGUSTA',
#   'county_fips_code': '51015',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-10',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'FRANKLIN',
#   'county_fips_code': '51067',
#   'age_group': '50 to 64 years',
#   'sex': 'Male',
#   'race': 'Black',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2021-04',
#   'res_state': 'ME',
#   'state_fips_code': '23',
#   'res_county': 'YORK',
#   'county_fips_code': '23031',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-07',
#   'res_state': 'HI',
#   'state_fips_code': '15',
#   'res_county': 'NA',
#   'county_fips_code': 'NA',
#   'age_group': '65+ years',
#   'sex': 'Male',
#   'race': 'Multiple/Other',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-11',
#   'res_state': 'MN',
#   'state_fips_code': '27',
#   'res_county': 'LYON',
#   'county_fips_code': '27083',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-10',
#   'res_state': 'KY',
#   'state_fips_code': '21',
#   'res_county': 'FAYETTE',
#   'county_fips_code': '21067',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-08',
#   'res_state': 'OK',
#   'state_fips_code': '40',
#   'res_county': 'CANADIAN',
#   'county_fips_code': '40017',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-07',
#   'res_state': 'NY',
#   'state_fips_code': '36',
#   'res_county': 'NASSAU',
#   'county_fips_code': '36059',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Missing',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-02',
#   'res_state': 'PA',
#   'state_fips_code': '42',
#   'res_county': 'NORTHAMPTON',
#   'county_fips_code': '42095',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'Unknown',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'Unknown'},
#  {'case_month': '2021-07',
#   'res_state': 'CA',
#   'state_fips_code': '06',
#   'res_county': 'SOLANO',
#   'county_fips_code': '06095',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Black',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-12',
#   'res_state': 'KS',
#   'state_fips_code': '20',
#   'res_county': 'BARTON',
#   'county_fips_code': '20009',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'No',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-09',
#   'res_state': 'KS',
#   'state_fips_code': '20',
#   'res_county': 'GEARY',
#   'county_fips_code': '20061',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2021-09',
#   'res_state': 'NC',
#   'state_fips_code': '37',
#   'res_county': 'ROWAN',
#   'county_fips_code': '37159',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Unknown',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Unknown',
#   'death_yn': 'No'},
#  {'case_month': '2020-11',
#   'res_state': 'SC',
#   'state_fips_code': '45',
#   'res_county': 'YORK',
#   'county_fips_code': '45091',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-07',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'ANDERSON',
#   'county_fips_code': '47001',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Asymptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2020-06',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'SUMNER',
#   'county_fips_code': '47165',
#   'age_group': '18 to 49 years',
#   'sex': 'Male',
#   'race': 'White',
#   'ethnicity': 'Hispanic/Latino',
#   'case_positive_specimen': '0',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No'},
#  {'case_month': '2021-01',
#   'res_state': 'CA',
#   'state_fips_code': '12',
#   'res_county': 'ORANGE',
#   'county_fips_code': '12095',
#   'age_group': '65+ years',
#   'sex': 'Female',
#   'race': 'Black',
#   'ethnicity': 'Non-Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-04',
#   'res_state': 'CA',
#   'state_fips_code': '06',
#   'res_county': 'SHASTA',
#   'county_fips_code': '06089',
#   'age_group': '65+ years',
#   'sex': 'Male',
#   'race': 'White',
#   'ethnicity': 'Non-Hispanic/Latino',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Asymptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2020-10',
#   'res_state': 'IL',
#   'state_fips_code': '17',
#   'res_county': 'MORGAN',
#   'county_fips_code': '17137',
#   'age_group': '18 to 49 years',
#   'sex': 'Missing',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-03',
#   'res_state': 'NH',
#   'state_fips_code': '33',
#   'res_county': 'GRAFTON',
#   'county_fips_code': '33009',
#   'age_group': '50 to 64 years',
#   'sex': 'NA',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Yes',
#   'icu_yn': 'Yes',
#   'death_yn': 'No'},
#  {'case_month': '2021-04',
#   'res_state': 'OH',
#   'state_fips_code': '39',
#   'res_county': 'BELMONT',
#   'county_fips_code': '39013',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Clinical evaluation',
#   'exposure_yn': 'Unknown',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'No',
#   'death_yn': 'No',
#   'underlying_conditions_yn': 'No'},
#  {'case_month': '2020-08',
#   'res_state': 'GA',
#   'state_fips_code': '13',
#   'res_county': 'CAMDEN',
#   'county_fips_code': '13039',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Unknown',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2021-01',
#   'res_state': 'VA',
#   'state_fips_code': '51',
#   'res_county': 'FREDERICKSBURG CITY',
#   'county_fips_code': '51630',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'MI',
#   'state_fips_code': '26',
#   'res_county': 'HOUGHTON',
#   'county_fips_code': '26061',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-12',
#   'res_state': 'AR',
#   'state_fips_code': '05',
#   'res_county': 'POINSETT',
#   'county_fips_code': '05111',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA',
#   'underlying_conditions_yn': 'Yes'},
#  {'case_month': '2020-12',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'SHAWANO',
#   'county_fips_code': '55115',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'NA'},
#  {'case_month': '2020-11',
#   'res_state': 'TN',
#   'state_fips_code': '47',
#   'res_county': 'SULLIVAN',
#   'county_fips_code': '47163',
#   'age_group': '0 - 17 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'case_positive_specimen': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-12',
#   'res_state': 'WI',
#   'state_fips_code': '55',
#   'res_county': 'BARRON',
#   'county_fips_code': '55005',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'Unknown',
#   'icu_yn': 'Missing',
#   'death_yn': 'Unknown'},
#  {'case_month': '2020-07',
#   'res_state': 'AL',
#   'state_fips_code': '01',
#   'res_county': 'DALLAS',
#   'county_fips_code': '01047',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Probable Case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'},
#  {'case_month': '2020-04',
#   'res_state': 'NY',
#   'state_fips_code': '36',
#   'res_county': 'GREENE',
#   'county_fips_code': '36039',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'NA',
#   'ethnicity': 'NA',
#   'case_positive_specimen': '1',
#   'case_onset_interval': '0',
#   'process': 'Missing',
#   'exposure_yn': 'Yes',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Symptomatic',
#   'hosp_yn': 'No',
#   'icu_yn': 'Missing',
#   'death_yn': 'No'},
#  {'case_month': '2021-01',
#   'res_state': 'SC',
#   'state_fips_code': '45',
#   'res_county': 'MARLBORO',
#   'county_fips_code': '45069',
#   'age_group': '18 to 49 years',
#   'sex': 'Female',
#   'race': 'Missing',
#   'ethnicity': 'Missing',
#   'process': 'Missing',
#   'exposure_yn': 'Missing',
#   'current_status': 'Laboratory-confirmed case',
#   'symptom_status': 'Missing',
#   'hosp_yn': 'Missing',
#   'icu_yn': 'Missing',
#   'death_yn': 'Missing'}]

# %%
# Vaccination and Case Trends by Age

covid19_vacc_trends_url = "https://data.cdc.gov/resource/rh2h-3yt2.json"
response2 = requests.get(covid19_vacc_trends_url)
response2
# Out:
# <Response [200]>

# %%
vacc_data_df= pd.read_json(covid19_vacc_trends_url)
vacc_data_df.head()
# Out:
#         date  mmwr_week location  administered_daily  administered_cumulative  \
# 0 2021-10-28         43       NV                   0                  3612712
# 1 2021-10-28         43       PA              149015                 17447607
# 2 2021-10-28         43       DC                   0                  1055543
# 3 2021-10-28         43       KS                   0                  3304696
# 4 2021-10-28         43       AL               21987                  4827200
#
#    administered_7_day_rolling  admin_dose_1_daily  admin_dose_1_cumulative  \
# 0                        5497                   0                  1963715
# 1                       49666               76669                  9900815
# 2                         586                   0                   569774
# 3                        5217                   0                  1763933
# 4                       13482                4997                  2610627
#
#    admin_dose_1_day_rolling date_type  administered_daily_change  \
# 0                      1479     Admin                          0
# 1                     25070    Report                     149015
# 2                       193     Admin                          0
# 3                      1419     Admin                          0
# 4                      3276    Report                      21987
#
#    administered_daily_change_1  series_complete_daily  \
# 0                         5497                      0
# 1                        49666                  22069
# 2                          587                      0
# 3                         5217                      0
# 4                        13482                   3696
#
#    series_complete_cumulative  series_complete_day_rolling
# 0                     1625323                         1087
# 1                     7724871                         9032
# 2                      439040                          146
# 3                     1545013                          720
# 4                     2187378                         3174

# %%
location_groups = vacc_data_df.groupby("location")
location_groups.sum()

location_groups_clean = location_groups[['location','admin_dose_1_cumulative','series_complete_cumulative']]
location_groups_sum = location_groups_clean.sum()

location_groups_sum.sort_values(by=['series_complete_cumulative'], ascending=False)
# Out:
#           admin_dose_1_cumulative  series_complete_cumulative
# location
# US                     3531251087                  3041895727
# CA                      496948367                   408981245
# TX                      308804501                   261384357
# NY                      229655411                   206132706
# FL                      238444101                   204202896
# IL                      156964945                   124147835
# PA                      157281951                   123270515
# OH                      111581248                   102578248
# NC                      120577206                    98765741
# NJ                      102723934                    93891845
# GA                      107538670                    91243067
# VA                      102527058                    91015871
# MI                       91063282                    85155404
# WA                       89128854                    81787424
# MA                       93056828                    81290228
# AZ                       81167615                    69116918
# MD                       74018646                    67687087
# IN                       65037540                    60111315
# WI                       62047601                    57421811
# MN                       61996277                    57125660
# CO                       62251594                    56453417
# TN                       60587353                    51794044
# MO                       56072827                    48599511
# OR                       51729944                    47500888
# SC                       50201788                    43422174
# CT                       47466155                    42682052
# PR                       46690300                    42087008
# KY                       44481189                    38975750
# LA                       42829119                    37420217
# AL                       41620663                    34879088
# OK                       37749670                    31459823
# IA                       31854857                    29653573
# NV                       33257144                    27529441
# UT                       31522385                    27271698
# KS                       29865657                    26191634
# AR                       27616169                    23017699
# MS                       24563551                    21632989
# NM                       23685751                    21133914
# NE                       19860534                    18425462
# ME                       17341083                    16050819
# NH                       17195233                    14486082
# HI                       17589030                    13491160
# ID                       14712908                    13221372
# WV                       14671802                    12482714
# RI                       12806367                    11955939
# DE                       10918632                     9285912
# MT                       10308976                     9111489
# VT                        8560067                     7524774
# SD                        8654236                     7404700
# DC                        9096489                     7010581
# AK                        7410933                     6514637
# ND                        6746461                     5573143
# WY                        5028352                     4290796
# GU                        2101791                     1926377
# VI                         916676                      779437
# FM                         771687                      684646
# MP                         614936                      589693
# AS                         560853                      493971
# MH                         377684                      323139
# RP                         284782                      250469
